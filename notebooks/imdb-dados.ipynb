# %%
import pandas as pd

nome_real_do_arquivo = 'title.basics.tsv' 
caminho_do_arquivo = f'../data/raw/{nome_real_do_arquivo}'

df = pd.read_csv(caminho_do_arquivo, sep='\t', low_memory=False) 

df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %%
print(f"O conjunto de dados possui {df.shape[0]} amostras (linhas) e {df.shape[1]} atributos (colunas).") 
print("\n" + "="*30 + "\n")

print("1. Tipos de Dados e Contagem de Não-Nulos:")
df.info()

print("\n" + "="*30 + "\n")

print("2. Estatísticas Descritivas:")
print(df.describe())

print("\n" + "="*30 + "\n")

print("3. Contagem de Valores Faltantes (df.isna().sum()):")
print(df.isna().sum())
# Out:
# O conjunto de dados possui 11953246 amostras (linhas) e 9 atributos (colunas).
#
# ...
#
# 1. Tipos de Dados e Contagem de Não-Nulos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11953246 entries, 0 to 11953245
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         int64
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: int64(1), object(8)
# memory usage: 820.8+ MB
#
# ...
#
# 2. Estatísticas Descritivas:
#             isAdult
# count  1.195325e+07
# mean   1.336766e-01
# std    1.414632e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    2.025000e+03
#
# ...
#
# 3. Contagem de Valores Faltantes (df.isna().sum()):
# tconst              0
# titleType           0
# primaryTitle       22
# ...

# %%
colunas_tabela = ['Nome da Variável', 'Tipo', 'Descrição', 'Unidades', 'Valores Faltantes']

data_imdb = [
    # [Nome, Tipo, Descrição, Unidades, Valores Faltantes]
    ['tconst', 'Categórico Regular', 'Identificador único do título no IMDb.', 'N/A', 'Não (0)'],
    ['titleType', 'Categórico Regular', 'Tipo de título (ex: movie, short, tvSeries).', 'N/A', 'Não (0)'],
    ['primaryTitle', 'Textual', 'O título principal na língua original.', 'N/A', 'Não (0)'],
    ['originalTitle', 'Textual', 'O título original do trabalho.', 'N/A', 'Não (0)'],
    ['isAdult', 'Categórico Regular (Binário)', '0 ou 1 se o título é considerado adulto.', 'N/A', 'Não (0)'],
    ['startYear', 'Numérico Discreto', r'O ano de lançamento (\N para nulos).', 'Anos', 'Não (0)'],
    ['endYear', 'Numérico Discreto', r'O ano final de produção (para séries, contém \N para nulos).', 'Anos', 'Não (0)'],
    ['runtimeMinutes', 'Numérico Contínuo', r'Duração primária do título, em minutos (contém \N para nulos).', 'Minutos', 'Não (0)'],
    ['genres', 'Categórico', 'Lista de até três gêneros associados ao título.', 'N/A', 'Sim (610)']
]

df_atributos = pd.DataFrame(data=data_imdb, columns=colunas_tabela)

df_atributos
# Out:
#   Nome da Variável                          Tipo  \
# 0           tconst            Categórico Regular
# 1        titleType            Categórico Regular
# 2     primaryTitle                       Textual
# 3    originalTitle                       Textual
# 4          isAdult  Categórico Regular (Binário)
# 5        startYear             Numérico Discreto
# 6          endYear             Numérico Discreto
# 7   runtimeMinutes             Numérico Contínuo
# 8           genres                    Categórico
#
#                                            Descrição Unidades  \
# 0             Identificador único do título no IMDb.      N/A
# 1       Tipo de título (ex: movie, short, tvSeries).      N/A
# 2             O título principal na língua original.      N/A
# 3                     O título original do trabalho.      N/A
# 4           0 ou 1 se o título é considerado adulto.      N/A
# 5        O ano de lançamento (contém \N para nulos).     Anos
# ...
